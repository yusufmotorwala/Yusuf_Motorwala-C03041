# %% [markdown]
# # Analysis of IPL Dataset

# %% [markdown]
# ***Exploratory Data Analysis***
#
#
# 1.   Exploratory data analysis is an approach to analyzing data sets to summarize their main characteristics, often with visual methods.
# 2.   In data science, it is often used as a starting point to gain insights about the dataset and understanding the features of the dataset.
# 3.  Data visualization is a very important part in data science as data nowadays is like oil, it increases continuosly and if it is not represented properly, valuable points/insights may be lost.

# %% [markdown]
# ![ipl.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Read the file

# %%
import pandas as pd

# %%
# if file is present in same dir
#pd.read_csv('matches.csv')

#if file is present in other directory
#pd.read_csv('C:\\Users\\hakim\\Batch_16\\matches.csv')
df = pd.read_csv(r'C:\Users\hakim\Batch_16\matches.csv')

# %% [markdown]
# # Fetch top 3 records

# %%
df.head(3)
# Out:
#    id    Season       city        date                team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017       Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
df.loc[:2]
# Out:
#    id    Season       city        date                team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017       Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
df.iloc[:3]
# Out:
#    id    Season       city        date                team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017       Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
df[:3] #default slicing work on rows
# Out:
#    id    Season       city        date                team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017       Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %% [markdown]
# # fetch last 3 records

# %%
df.tail(3)
# Out:
#         id    Season           city        date                team1  \
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019  Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019       Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019       Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 753           0       Delhi Capitals            0               2
# 754           0  Chennai Super Kings            0               6
# 755           0       Mumbai Indians            1               0
#
#     player_of_match                               venue        umpire1  \
# 753         RR Pant                    ACA-VDCA Stadium            NaN
# ...

# %% [markdown]
# # How many rows and columns present?

# %%
df.shape
# Out:
# (756, 18)

# %%
print('Total number of rows:',df.shape[0],'\nTotal number of columns:',df.shape[1])
# Out:
# Total number of rows: 756
# Total number of columns: 18

# %% [markdown]
# # List out the names of columns

# %%
df.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %% [markdown]
# # check the abstract summary of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %% [markdown]
# # check the missing values

# %%
df.isna().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %% [markdown]
# From above, we have different columns in which data is missing, are as follows
# - city 7
# - winner 4
# - player_of _match 4
# - ump1, ump2 2 each
# - umpi3 637
#
#
# So its better to drop ump3 column

# %%
df.drop(columns='umpire3',inplace=True)

# %%
#lets work on City
df.city.describe()
# Out:
# count        749
# unique        32
# top       Mumbai
# freq         101
# Name: city, dtype: object

# %%
#most of the matches played at Mumbai so we are going to fill by same
df.city = df.city.fillna('Mumbai')

# %%
df.isna().sum()
# Out:
# id                 0
# Season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             4
# win_by_runs        0
# win_by_wickets     0
# player_of_match    4
# venue              0
# umpire1            2
# umpire2            2
# dtype: int64

# %%
df.dl_applied.sum()
# Out:
# 19

# %% [markdown]
# # check descriptive statistics

# %%
df.describe()
# Out:
#                  id  dl_applied  win_by_runs  win_by_wickets
# count    756.000000  756.000000   756.000000      756.000000
# mean    1792.178571    0.025132    13.283069        3.350529
# std     3464.478148    0.156630    23.471144        3.387963
# min        1.000000    0.000000     0.000000        0.000000
# 25%      189.750000    0.000000     0.000000        0.000000
# 50%      378.500000    0.000000     0.000000        4.000000
# 75%      567.250000    0.000000    19.000000        6.000000
# max    11415.000000    1.000000   146.000000       10.000000

# %% [markdown]
# # check the data of any column

# %%
df.venue
# Out:
# 0      Rajiv Gandhi International Stadium, Uppal
# 1        Maharashtra Cricket Association Stadium
# 2         Saurashtra Cricket Association Stadium
# 3                         Holkar Cricket Stadium
# 4                          M Chinnaswamy Stadium
#                          ...
# 751                             Wankhede Stadium
# 752                    M. A. Chidambaram Stadium
# 753                             ACA-VDCA Stadium
# 754                             ACA-VDCA Stadium
# 755           Rajiv Gandhi Intl. Cricket Stadium
# Name: venue, Length: 756, dtype: object

# %%
df[['toss_winner']]
# Out:
#                      toss_winner
# 0    Royal Challengers Bangalore
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ..                           ...
# 751               Mumbai Indians
# 752          Chennai Super Kings
# 753               Delhi Capitals
# 754          Chennai Super Kings
# 755               Mumbai Indians
#
# [756 rows x 1 columns]

# %% [markdown]
# # Fetch City and result column

# %%
#df.loc[:,['city','result']]
df[['city','result']]
# Out:
#               city  result
# 0        Hyderabad  normal
# 1             Pune  normal
# 2           Rajkot  normal
# 3           Indore  normal
# 4        Bangalore  normal
# ..             ...     ...
# 751         Mumbai  normal
# 752        Chennai  normal
# 753  Visakhapatnam  normal
# 754  Visakhapatnam  normal
# 755      Hyderabad  normal
#
# [756 rows x 2 columns]

# %% [markdown]
# # Fetch the data of Season 2017

# %%
df.groupby('Season').get_group('IPL-2017')
# Out:
#     id    Season        city        date                        team1  \
# 0    1  IPL-2017   Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1    2  IPL-2017        Pune  06-04-2017               Mumbai Indians
# 2    3  IPL-2017      Rajkot  07-04-2017                Gujarat Lions
# 3    4  IPL-2017      Indore  08-04-2017       Rising Pune Supergiant
# 4    5  IPL-2017   Bangalore  08-04-2017  Royal Challengers Bangalore
# 5    6  IPL-2017   Hyderabad  09-04-2017                Gujarat Lions
# 6    7  IPL-2017      Mumbai  09-04-2017        Kolkata Knight Riders
# 7    8  IPL-2017      Indore  10-04-2017  Royal Challengers Bangalore
# 8    9  IPL-2017        Pune  11-04-2017             Delhi Daredevils
# 9   10  IPL-2017      Mumbai  12-04-2017          Sunrisers Hyderabad
# 10  11  IPL-2017     Kolkata  13-04-2017              Kings XI Punjab
# 11  12  IPL-2017   Bangalore  14-04-2017  Royal Challengers Bangalore
# ...

# %%
df[df.Season == 'IPL-2017']
# Out:
#     id    Season        city        date                        team1  \
# 0    1  IPL-2017   Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1    2  IPL-2017        Pune  06-04-2017               Mumbai Indians
# 2    3  IPL-2017      Rajkot  07-04-2017                Gujarat Lions
# 3    4  IPL-2017      Indore  08-04-2017       Rising Pune Supergiant
# 4    5  IPL-2017   Bangalore  08-04-2017  Royal Challengers Bangalore
# 5    6  IPL-2017   Hyderabad  09-04-2017                Gujarat Lions
# 6    7  IPL-2017      Mumbai  09-04-2017        Kolkata Knight Riders
# 7    8  IPL-2017      Indore  10-04-2017  Royal Challengers Bangalore
# 8    9  IPL-2017        Pune  11-04-2017             Delhi Daredevils
# 9   10  IPL-2017      Mumbai  12-04-2017          Sunrisers Hyderabad
# 10  11  IPL-2017     Kolkata  13-04-2017              Kings XI Punjab
# 11  12  IPL-2017   Bangalore  14-04-2017  Royal Challengers Bangalore
# ...

# %%
df.query('Season == "IPL-2017"')
# Out:
#     id    Season        city        date                        team1  \
# 0    1  IPL-2017   Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1    2  IPL-2017        Pune  06-04-2017               Mumbai Indians
# 2    3  IPL-2017      Rajkot  07-04-2017                Gujarat Lions
# 3    4  IPL-2017      Indore  08-04-2017       Rising Pune Supergiant
# 4    5  IPL-2017   Bangalore  08-04-2017  Royal Challengers Bangalore
# 5    6  IPL-2017   Hyderabad  09-04-2017                Gujarat Lions
# 6    7  IPL-2017      Mumbai  09-04-2017        Kolkata Knight Riders
# 7    8  IPL-2017      Indore  10-04-2017  Royal Challengers Bangalore
# 8    9  IPL-2017        Pune  11-04-2017             Delhi Daredevils
# 9   10  IPL-2017      Mumbai  12-04-2017          Sunrisers Hyderabad
# 10  11  IPL-2017     Kolkata  13-04-2017              Kings XI Punjab
# 11  12  IPL-2017   Bangalore  14-04-2017  Royal Challengers Bangalore
# ...

# %%
df.Season
#remove IPL prefix from Season column
# Out:
# 0      IPL-2017
# 1      IPL-2017
# 2      IPL-2017
# 3      IPL-2017
# 4      IPL-2017
#          ...
# 751    IPL-2019
# 752    IPL-2019
# 753    IPL-2019
# 754    IPL-2019
# 755    IPL-2019
# Name: Season, Length: 756, dtype: object

# %%
df.Season.str.split('-').apply(lambda x:x[1])
# Out:
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
#        ...
# 751    2019
# 752    2019
# 753    2019
# 754    2019
# 755    2019
# Name: Season, Length: 756, dtype: object

# %%
df.Season.str.split('-',expand=True)[1]
# Out:
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
#        ...
# 751    2019
# 752    2019
# 753    2019
# 754    2019
# 755    2019
# Name: 1, Length: 756, dtype: object

# %%
df.Season.str.replace('IPL-','')
# Out:
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
#        ...
# 751    2019
# 752    2019
# 753    2019
# 754    2019
# 755    2019
# Name: Season, Length: 756, dtype: object

# %%
df.Season.map({'IPL-2017':'2017',
            'IPL-2019':'2019'})
# Out:
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
#        ...
# 751    2019
# 752    2019
# 753    2019
# 754    2019
# 755    2019
# Name: Season, Length: 756, dtype: object

# %% [markdown]
# # How many matches played in season 2018

# %% [markdown]
# # How many matches played at Rajiv Gandhi International Stadium, Uppal

# %% [markdown]
# # Show the total seasons in dataset

# %% [markdown]
# # How many seasons data we have?

# %% [markdown]
# # Let us get some basic stats #
# ## How many Number of matches played so far

# %% [markdown]
# # plot the count of matches played each season

# %% [markdown]
# # Number of Matches played in each venue

# %% [markdown]
# # Top 5 venues and most matches played

# %% [markdown]
# # Which Team won the most of tosses

# %% [markdown]
# # who is the winner of season 2018

# %% [markdown]
# # Top 5 venues and most matches played

# %% [markdown]
# # Which Team won the most of tosses

# %% [markdown]
# # who won the final match of season 2019?

# %% [markdown]
# # who is the winner of season 2018

# %% [markdown]
# # Number of Matches played by each Team

# %% [markdown]
# # Show the % of toss_decision

# %% [markdown]
# # How many matches MI won till now?

# %% [markdown]
# # How many matche played between MI and CSK

# %% [markdown]
# # Find out top 10 player_of_match from season 2013

# %% [markdown]
# # How many times by Sachine Tendulkar received player_of _match award

# %% [markdown]
# # Find out the count of total no of matches played in Mumbai and Delhi

# %% [markdown]
# # If my place is Pune and Team is Delhi Daredevils then how many times they won?
