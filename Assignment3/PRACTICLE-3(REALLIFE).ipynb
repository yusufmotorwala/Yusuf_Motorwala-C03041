# %%
import pandas as pd

# %%
df1= pd.read_csv("indian.csv")

# %%
df1
# Out:
#     Employee ID Employee   Age Department    Salary Joining Date  \
# 0          1001    Suman  50.0         HR   86250.0    1/31/2015
# 1          1002    Kiran  36.0    Finance  102082.0    2/28/2015
# 2          1003   Aditya  29.0      Sales   64754.0    3/31/2015
# 3          1004      NaN  42.0    Finance   41411.0    4/30/2015
# 4          1005   Vihaan  40.0         HR   32911.0    5/31/2015
# ..          ...      ...   ...        ...       ...          ...
# 95         1096   Pankaj  58.0    Finance       NaN   12/31/2022
# 96         1097   Suresh  56.0      Sales   48589.0    1/31/2023
# 97         1098   Ananya  43.0    Finance   73484.0    2/28/2023
# 98         1099   Manish  48.0  Marketing  112989.0    3/31/2023
# 99         1100   Vihaan  56.0  Marketing   66212.0    4/30/2023
#
#     Experience (Years)  Performance Rating
# 0                  NaN                 1.0
# 1                  3.0                 5.0
# 2                  9.0                 2.0
# ...

# %%
df1.head()
# Out:
#    Employee ID Employee   Age Department    Salary Joining Date  \
# 0         1001    Suman  50.0         HR   86250.0    1/31/2015
# 1         1002    Kiran  36.0    Finance  102082.0    2/28/2015
# 2         1003   Aditya  29.0      Sales   64754.0    3/31/2015
# 3         1004      NaN  42.0    Finance   41411.0    4/30/2015
# 4         1005   Vihaan  40.0         HR   32911.0    5/31/2015
#
#    Experience (Years)  Performance Rating
# 0                 NaN                 1.0
# 1                 3.0                 5.0
# 2                 9.0                 2.0
# 3                 5.0                 2.0
# 4                17.0                 5.0

# %%
df1.tail()
# Out:
#     Employee ID Employee   Age Department    Salary Joining Date  \
# 95         1096   Pankaj  58.0    Finance       NaN   12/31/2022
# 96         1097   Suresh  56.0      Sales   48589.0    1/31/2023
# 97         1098   Ananya  43.0    Finance   73484.0    2/28/2023
# 98         1099   Manish  48.0  Marketing  112989.0    3/31/2023
# 99         1100   Vihaan  56.0  Marketing   66212.0    4/30/2023
#
#     Experience (Years)  Performance Rating
# 95                12.0                 1.0
# 96                 NaN                 3.0
# 97                16.0                 4.0
# 98                 7.0                 1.0
# 99                 4.0                 4.0

# %%
df1.isnull()
# Out:
#     Employee ID  Employee    Age  Department  Salary  Joining Date  \
# 0         False     False  False       False   False         False
# 1         False     False  False       False   False         False
# 2         False     False  False       False   False         False
# 3         False      True  False       False   False         False
# 4         False     False  False       False   False         False
# ..          ...       ...    ...         ...     ...           ...
# 95        False     False  False       False    True         False
# 96        False     False  False       False   False         False
# 97        False     False  False       False   False         False
# 98        False     False  False       False   False         False
# 99        False     False  False       False   False         False
#
#     Experience (Years)  Performance Rating
# 0                 True               False
# 1                False               False
# ...

# %%
df1.isnull()
# Out:
#     Employee ID  Employee    Age  Department  Salary  Joining Date  \
# 0         False     False  False       False   False         False
# 1         False     False  False       False   False         False
# 2         False     False  False       False   False         False
# 3         False      True  False       False   False         False
# 4         False     False  False       False   False         False
# ..          ...       ...    ...         ...     ...           ...
# 95        False     False  False       False    True         False
# 96        False     False  False       False   False         False
# 97        False     False  False       False   False         False
# 98        False     False  False       False   False         False
# 99        False     False  False       False   False         False
#
#     Experience (Years)  Performance Rating
# 0                 True               False
# 1                False               False
# ...

# %%
df1.isna()
# Out:
#     Employee ID  Employee    Age  Department  Salary  Joining Date  \
# 0         False     False  False       False   False         False
# 1         False     False  False       False   False         False
# 2         False     False  False       False   False         False
# 3         False      True  False       False   False         False
# 4         False     False  False       False   False         False
# ..          ...       ...    ...         ...     ...           ...
# 95        False     False  False       False    True         False
# 96        False     False  False       False   False         False
# 97        False     False  False       False   False         False
# 98        False     False  False       False   False         False
# 99        False     False  False       False   False         False
#
#     Experience (Years)  Performance Rating
# 0                 True               False
# 1                False               False
# ...

# %%
df1.isna().count()
# Out:
# Employee ID           100
# Employee              100
# Age                   100
# Department            100
# Salary                100
# Joining Date          100
# Experience (Years)    100
# Performance Rating    100
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# Employee ID            0
# Employee               2
# Age                   10
# Department            10
# Salary                10
# Joining Date           0
# Experience (Years)    10
# Performance Rating    10
# dtype: int64

# %%
df1.describe()
# Out:
#        Employee ID        Age         Salary  Experience (Years)  \
# count   100.000000  90.000000      90.000000           90.000000
# mean   1050.500000  40.022222   72394.355556            9.677778
# std      29.011492  10.655987   26437.783192            5.702016
# min    1001.000000  22.000000   31802.000000            1.000000
# 25%    1025.750000  30.250000   49761.000000            5.000000
# 50%    1050.500000  41.500000   73250.000000           10.000000
# 75%    1075.250000  47.750000   95376.000000           15.000000
# max    1100.000000  59.000000  118614.000000           19.000000
#
#        Performance Rating
# count           90.000000
# mean             3.022222
# std              1.476237
# min              1.000000
# 25%              2.000000
# 50%              3.000000
# 75%              4.000000
# max              5.000000

# %%
df1.shape[0]
# Out:
# 100

# %%
df1.shape[1]
# Out:
# 8

# %%
df1.dtypes
# Out:
# Employee ID             int64
# Employee               object
# Age                   float64
# Department             object
# Salary                float64
# Joining Date           object
# Experience (Years)    float64
# Performance Rating    float64
# dtype: object

# %%
df1['Age'] = df1['Age'].fillna(0).astype('int')

# %%
df1.dtypes
# Out:
# Employee ID             int64
# Employee               object
# Age                     int32
# Department             object
# Salary                float64
# Joining Date           object
# Experience (Years)    float64
# Performance Rating    float64
# dtype: object

# %%
#for know the year the empoye works
current = pd.to_datetime('today')

# %%
df1=df1.drop_duplicates() ### TO DROP THE DUPLICTAE VALUES

# %%
df1
# Out:
#     Employee ID Employee  Age Department    Salary Joining Date  \
# 0          1001    Suman   50         HR   86250.0    1/31/2015
# 1          1002    Kiran   36    Finance  102082.0    2/28/2015
# 2          1003   Aditya   29      Sales   64754.0    3/31/2015
# 3          1004      NaN   42    Finance   41411.0    4/30/2015
# 4          1005   Vihaan   40         HR   32911.0    5/31/2015
# ..          ...      ...  ...        ...       ...          ...
# 95         1096   Pankaj   58    Finance       NaN   12/31/2022
# 96         1097   Suresh   56      Sales   48589.0    1/31/2023
# 97         1098   Ananya   43    Finance   73484.0    2/28/2023
# 98         1099   Manish   48  Marketing  112989.0    3/31/2023
# 99         1100   Vihaan   56  Marketing   66212.0    4/30/2023
#
#     Experience (Years)  Performance Rating
# 0                  NaN                 1.0
# 1                  3.0                 5.0
# 2                  9.0                 2.0
# ...

# %%
df1.shape
# Out:
# (100, 8)

# %%
df1.isna().sum()
# Out:
# Employee ID            0
# Employee               2
# Age                    0
# Department            10
# Salary                10
# Joining Date           0
# Experience (Years)    10
# Performance Rating    10
# dtype: int64

# %%
df1['Joining Date'] = pd.to_datetime(df1['Joining Date'])

# %%
#for know the year the empoye works
current = pd.to_datetime('today')
df1['MYLIFE'] = (current - df1['Joining Date']).dt.days / 365.25

# %%
df1
# Out:
#     Employee ID Employee  Age Department    Salary Joining Date  \
# 0          1001    Suman   50         HR   86250.0   2015-01-31
# 1          1002    Kiran   36    Finance  102082.0   2015-02-28
# 2          1003   Aditya   29      Sales   64754.0   2015-03-31
# 3          1004      NaN   42    Finance   41411.0   2015-04-30
# 4          1005   Vihaan   40         HR   32911.0   2015-05-31
# ..          ...      ...  ...        ...       ...          ...
# 95         1096   Pankaj   58    Finance       NaN   2022-12-31
# 96         1097   Suresh   56      Sales   48589.0   2023-01-31
# 97         1098   Ananya   43    Finance   73484.0   2023-02-28
# 98         1099   Manish   48  Marketing  112989.0   2023-03-31
# 99         1100   Vihaan   56  Marketing   66212.0   2023-04-30
#
#     Experience (Years)  Performance Rating     MYLIFE
# 0                  NaN                 1.0  10.069815
# 1                  3.0                 5.0   9.993155
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df4 = pd.read_csv("indian.csv")


plt.figure(figsize=(8,5))
sns.histplot(df4['Salary'], kde=True, bins=30, color='blue')
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.show()
