# %%
import pandas as pd

# %%
df = pd.read_csv("dt.csv")

# %%
df
# Out:
#                Name  projects-done  Tech ID                  Role  \
# 0   Adityaraj Patil            2.0      1.0       Project Manager
# 1      Isha Gaikwad            2.0      2.0        UI/UX Designer
# 2      Anisha Dhuri            2.0      3.0        UI/UX Designer
# 3    Kaveri Gaikwad            2.0      4.0  Cybersecurity Intern
# 4   Sakshi Chudekar            2.0      5.0       Project Manager
# 5     Dixita Jadhav            2.0      NaN     Backend Developer
# 6             Swati            2.0      7.0     Backend Developer
# 7    Rohan Deshmukh            2.0      8.0        UI/UX Designer
# 8    Priya Kulkarni            2.0      9.0     Backend Developer
# 9      Vivek Sharma            2.0     10.0           AI Engineer
# 10      Sneha Joshi            2.0     11.0  Cybersecurity Intern
# 11       Amit Patil            2.0     12.0           AI Engineer
# 12     Pooja Shinde            2.0      NaN         Web Developer
# ...

# %%
df.shape
# Out:
# (30, 5)

# %%
df.isnull()
# Out:
#      Name  projects-done  Tech ID   Role  Project Worked On
# 0   False          False    False  False              False
# 1   False          False    False  False              False
# 2   False          False    False  False              False
# 3   False          False    False  False              False
# 4   False          False    False  False               True
# 5   False          False     True  False              False
# 6   False          False    False  False              False
# 7   False          False    False  False              False
# 8   False          False    False  False              False
# 9   False          False    False  False              False
# 10  False          False    False  False              False
# 11  False          False    False  False               True
# 12  False          False     True  False              False
# 13  False          False    False  False              False
# 14  False          False    False  False              False
# ...

# %%
df.isnull().sum()
# Out:
# Name                 0
# projects-done        1
# Tech ID              2
# Role                 0
# Project Worked On    5
# dtype: int64

# %%
df.head
# Out:
# <bound method NDFrame.head of                Name  projects-done  Tech ID                  Role  \
# 0   Adityaraj Patil            2.0      1.0       Project Manager
# 1      Isha Gaikwad            2.0      2.0        UI/UX Designer
# 2      Anisha Dhuri            2.0      3.0        UI/UX Designer
# 3    Kaveri Gaikwad            2.0      4.0  Cybersecurity Intern
# 4   Sakshi Chudekar            2.0      5.0       Project Manager
# 5     Dixita Jadhav            2.0      NaN     Backend Developer
# 6             Swati            2.0      7.0     Backend Developer
# 7    Rohan Deshmukh            2.0      8.0        UI/UX Designer
# 8    Priya Kulkarni            2.0      9.0     Backend Developer
# 9      Vivek Sharma            2.0     10.0           AI Engineer
# 10      Sneha Joshi            2.0     11.0  Cybersecurity Intern
# 11       Amit Patil            2.0     12.0           AI Engineer
# 12     Pooja Shinde            2.0      NaN         Web Developer
# ...

# %%
df.describe()
# Out:
#        projects-done    Tech ID
# count           29.0  28.000000
# mean             2.0  15.928571
# std              0.0   8.914942
# min              2.0   1.000000
# 25%              2.0   8.750000
# 50%              2.0  16.500000
# 75%              2.0  23.250000
# max              2.0  30.000000

# %%
df.drop_duplicates()
# Out:
#                Name  projects-done  Tech ID                  Role  \
# 0   Adityaraj Patil            2.0      1.0       Project Manager
# 1      Isha Gaikwad            2.0      2.0        UI/UX Designer
# 2      Anisha Dhuri            2.0      3.0        UI/UX Designer
# 3    Kaveri Gaikwad            2.0      4.0  Cybersecurity Intern
# 4   Sakshi Chudekar            2.0      5.0       Project Manager
# 5     Dixita Jadhav            2.0      NaN     Backend Developer
# 6             Swati            2.0      7.0     Backend Developer
# 7    Rohan Deshmukh            2.0      8.0        UI/UX Designer
# 8    Priya Kulkarni            2.0      9.0     Backend Developer
# 9      Vivek Sharma            2.0     10.0           AI Engineer
# 10      Sneha Joshi            2.0     11.0  Cybersecurity Intern
# 11       Amit Patil            2.0     12.0           AI Engineer
# 12     Pooja Shinde            2.0      NaN         Web Developer
# ...

# %%
df.bfill()
# Out:
#                Name  projects-done  Tech ID                  Role  \
# 0   Adityaraj Patil            2.0      1.0       Project Manager
# 1      Isha Gaikwad            2.0      2.0        UI/UX Designer
# 2      Anisha Dhuri            2.0      3.0        UI/UX Designer
# 3    Kaveri Gaikwad            2.0      4.0  Cybersecurity Intern
# 4   Sakshi Chudekar            2.0      5.0       Project Manager
# 5     Dixita Jadhav            2.0      7.0     Backend Developer
# 6             Swati            2.0      7.0     Backend Developer
# 7    Rohan Deshmukh            2.0      8.0        UI/UX Designer
# 8    Priya Kulkarni            2.0      9.0     Backend Developer
# 9      Vivek Sharma            2.0     10.0           AI Engineer
# 10      Sneha Joshi            2.0     11.0  Cybersecurity Intern
# 11       Amit Patil            2.0     12.0           AI Engineer
# 12     Pooja Shinde            2.0     14.0         Web Developer
# ...

# %%
df.ffill()
# Out:
#                Name  projects-done  Tech ID                  Role  \
# 0   Adityaraj Patil            2.0      1.0       Project Manager
# 1      Isha Gaikwad            2.0      2.0        UI/UX Designer
# 2      Anisha Dhuri            2.0      3.0        UI/UX Designer
# 3    Kaveri Gaikwad            2.0      4.0  Cybersecurity Intern
# 4   Sakshi Chudekar            2.0      5.0       Project Manager
# 5     Dixita Jadhav            2.0      5.0     Backend Developer
# 6             Swati            2.0      7.0     Backend Developer
# 7    Rohan Deshmukh            2.0      8.0        UI/UX Designer
# 8    Priya Kulkarni            2.0      9.0     Backend Developer
# 9      Vivek Sharma            2.0     10.0           AI Engineer
# 10      Sneha Joshi            2.0     11.0  Cybersecurity Intern
# 11       Amit Patil            2.0     12.0           AI Engineer
# 12     Pooja Shinde            2.0     12.0         Web Developer
# ...

# %%
df.fillna(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df.fillna(x)
#
# NameError: name 'x' is not defined
